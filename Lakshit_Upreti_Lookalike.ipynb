# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')

customers = pd.read_csv('/content/drive/My Drive/Zeotap/Customers.csv')
products = pd.read_csv('/content/drive/My Drive/Zeotap/Products.csv')
transactions = pd.read_csv('/content/drive/My Drive/Zeotap/Transactions.csv')
# Out:
# Mounted at /content/drive

# %%
df = transactions.merge(customers, on="CustomerID", how="left")
df = df.merge(products, on="ProductID", how="left")

df.head()
# Out:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23         1
# 1        T00112      C0146      P067  2024-05-27 22:23:54         1
# 2        T00166      C0127      P067  2024-04-25 07:38:55         1
# 3        T00272      C0087      P067  2024-03-26 22:55:37         2
# 4        T00363      C0070      P067  2024-03-21 15:10:10         3
#
#    TotalValue  Price_x     CustomerName         Region  SignupDate  \
# 0      300.68   300.68   Andrea Jenkins         Europe  2022-12-03
# 1      300.68   300.68  Brittany Harvey           Asia  2024-09-04
# 2      300.68   300.68  Kathryn Stevens         Europe  2024-04-04
# 3      601.36   300.68  Travis Campbell  South America  2024-04-11
# 4      902.04   300.68    Timothy Perez         Europe  2022-03-15
#
#                        ProductName     Category  Price_y
# 0  ComfortLiving Bluetooth Speaker  Electronics   300.68
# 1  ComfortLiving Bluetooth Speaker  Electronics   300.68
# 2  ComfortLiving Bluetooth Speaker  Electronics   300.68
# 3  ComfortLiving Bluetooth Speaker  Electronics   300.68
# 4  ComfortLiving Bluetooth Speaker  Electronics   300.68

# %%
df = df.drop(columns=['Price_x'])
df = df.rename(columns={'Price_y': 'Price'})

df.head()
# Out:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23         1
# 1        T00112      C0146      P067  2024-05-27 22:23:54         1
# 2        T00166      C0127      P067  2024-04-25 07:38:55         1
# 3        T00272      C0087      P067  2024-03-26 22:55:37         2
# 4        T00363      C0070      P067  2024-03-21 15:10:10         3
#
#    TotalValue     CustomerName         Region  SignupDate  \
# 0      300.68   Andrea Jenkins         Europe  2022-12-03
# 1      300.68  Brittany Harvey           Asia  2024-09-04
# 2      300.68  Kathryn Stevens         Europe  2024-04-04
# 3      601.36  Travis Campbell  South America  2024-04-11
# 4      902.04    Timothy Perez         Europe  2022-03-15
#
#                        ProductName     Category   Price
# 0  ComfortLiving Bluetooth Speaker  Electronics  300.68
# 1  ComfortLiving Bluetooth Speaker  Electronics  300.68
# 2  ComfortLiving Bluetooth Speaker  Electronics  300.68
# 3  ComfortLiving Bluetooth Speaker  Electronics  300.68
# 4  ComfortLiving Bluetooth Speaker  Electronics  300.68

# %% [markdown]
# # Normalizing Total Vale, Quantity and Price

# %%
from sklearn.preprocessing import MinMaxScaler

num_cols = ["Quantity", "Price", "TotalValue"]
scaler = MinMaxScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df.head()
# Out:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23  0.000000
# 1        T00112      C0146      P067  2024-05-27 22:23:54  0.000000
# 2        T00166      C0127      P067  2024-04-25 07:38:55  0.000000
# 3        T00272      C0087      P067  2024-03-26 22:55:37  0.333333
# 4        T00363      C0070      P067  2024-03-21 15:10:10  0.666667
#
#    TotalValue     CustomerName         Region  SignupDate  \
# 0    0.144104   Andrea Jenkins         Europe  2022-12-03
# 1    0.144104  Brittany Harvey           Asia  2024-09-04
# 2    0.144104  Kathryn Stevens         Europe  2024-04-04
# 3    0.296350  Travis Campbell  South America  2024-04-11
# 4    0.448596    Timothy Perez         Europe  2022-03-15
#
#                        ProductName     Category     Price
# 0  ComfortLiving Bluetooth Speaker  Electronics  0.590849
# 1  ComfortLiving Bluetooth Speaker  Electronics  0.590849
# 2  ComfortLiving Bluetooth Speaker  Electronics  0.590849
# 3  ComfortLiving Bluetooth Speaker  Electronics  0.590849
# 4  ComfortLiving Bluetooth Speaker  Electronics  0.590849

# %% [markdown]
# # Encoding "Region" and "Category"

# %%
ndf = pd.get_dummies(df, columns=['Region', 'Category'], drop_first=False)

ndf.head()
# Out:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23  0.000000
# 1        T00112      C0146      P067  2024-05-27 22:23:54  0.000000
# 2        T00166      C0127      P067  2024-04-25 07:38:55  0.000000
# 3        T00272      C0087      P067  2024-03-26 22:55:37  0.333333
# 4        T00363      C0070      P067  2024-03-21 15:10:10  0.666667
#
#    TotalValue     CustomerName  SignupDate                      ProductName  \
# 0    0.144104   Andrea Jenkins  2022-12-03  ComfortLiving Bluetooth Speaker
# 1    0.144104  Brittany Harvey  2024-09-04  ComfortLiving Bluetooth Speaker
# 2    0.144104  Kathryn Stevens  2024-04-04  ComfortLiving Bluetooth Speaker
# 3    0.296350  Travis Campbell  2024-04-11  ComfortLiving Bluetooth Speaker
# 4    0.448596    Timothy Perez  2022-03-15  ComfortLiving Bluetooth Speaker
#
#       Price  Region_Asia  Region_Europe  Region_North America  \
# 0  0.590849        False           True                 False
# 1  0.590849         True          False                 False
# 2  0.590849        False           True                 False
# 3  0.590849        False          False                 False
# 4  0.590849        False           True                 False
#
#    Region_South America  Category_Books  Category_Clothing  \
# 0                 False           False              False
# 1                 False           False              False
# 2                 False           False              False
# 3                  True           False              False
# 4                 False           False              False
#
#    Category_Electronics  Category_Home Decor
# 0                  True                False
# 1                  True                False
# 2                  True                False
# 3                  True                False
# 4                  True                False

# %%
from sklearn.neighbors import NearestNeighbors

numeric_columns = ndf.select_dtypes(include=['float64', 'int64']).columns

features = ndf[numeric_columns]

knn = NearestNeighbors(n_neighbors=4, metric='cosine')
knn.fit(features)

lookalikes = {}

for cust_id in ndf['CustomerID'][:20]:
    customer_idx = ndf[ndf['CustomerID'] == cust_id].index[0]

    distances, indices = knn.kneighbors(features.iloc[customer_idx].values.reshape(1, -1))

    similar_customers = []
    similarity_scores = []

    for i, idx in enumerate(indices[0]):
        if ndf['CustomerID'].iloc[idx] != cust_id:
            similar_customers.append(ndf['CustomerID'].iloc[idx])
            similarity_scores.append(1 - distances[0][i])

    lookalikes[cust_id] = list(zip(similar_customers[:3], similarity_scores[:3]))

lookalike_df = pd.DataFrame(list(lookalikes.items()), columns=['CustomerID', 'Lookalikes'])

# %%
lookalike_df.to_csv('Lakshit_Upreti_Lookalike.csv', index=False)

lookalike_df
# Out:
#    CustomerID                                         Lookalikes
# 0       C0199         [(C0179, 1.0), (C0100, 1.0), (C0177, 1.0)]
# 1       C0146         [(C0179, 1.0), (C0100, 1.0), (C0177, 1.0)]
# 2       C0127         [(C0179, 1.0), (C0100, 1.0), (C0177, 1.0)]
# 3       C0087         [(C0155, 1.0), (C0130, 1.0), (C0075, 1.0)]
# 4       C0070         [(C0051, 1.0), (C0157, 1.0), (C0195, 1.0)]
# 5       C0188         [(C0179, 1.0), (C0100, 1.0), (C0177, 1.0)]
# 6       C0195         [(C0070, 1.0), (C0051, 1.0), (C0157, 1.0)]
# 7       C0008         [(C0179, 1.0), (C0100, 1.0), (C0177, 1.0)]
# 8       C0157         [(C0070, 1.0), (C0051, 1.0), (C0195, 1.0)]
# 9       C0130         [(C0087, 1.0), (C0155, 1.0), (C0075, 1.0)]
# 10      C0051         [(C0070, 1.0), (C0157, 1.0), (C0195, 1.0)]
# 11      C0075         [(C0087, 1.0), (C0155, 1.0), (C0130, 1.0)]
# 12      C0155         [(C0087, 1.0), (C0130, 1.0), (C0075, 1.0)]
# 13      C0092  [(C0088, 1.0), (C0109, 0.9999604308701864), (C...
# 14      C0088  [(C0092, 1.0), (C0109, 0.9999604308701864), (C...
# 15      C0109  [(C0200, 1.0), (C0041, 1.0), (C0170, 0.9999664...
# 16      C0041  [(C0200, 1.0), (C0109, 1.0), (C0170, 0.9999664...
# 17      C0101  [(C0094, 0.999958548161212), (C0011, 0.9999585...
# 18      C0154         [(C0025, 1.0), (C0097, 1.0), (C0051, 1.0)]
# 19      C0200  [(C0041, 1.0), (C0109, 1.0), (C0170, 0.9999664...
